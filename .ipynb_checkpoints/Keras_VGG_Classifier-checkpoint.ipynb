# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
from keras.applications.vgg16 import VGG16

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import preprocess_input
from keras.layers import Input, Flatten, Dense, Dropout
from keras.models import Model, load_model

from keras.optimizers import SGD

from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
# Out:
# c:\users\hiro\anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Create new model using vgg Features

# %%
'''Re-initialize my_model using vgg16 features'''
# #https://github.com/keras-team/keras/issues/4465

#Get back the convolutional part of a VGG network trained on ImageNet
model_vgg16_conv = VGG16(weights='imagenet', include_top=False)
# model_vgg16_conv.summary()

#Input
input = Input(shape = (150,150,3), name = 'image_input')

#Freeze vgg layers
model_vgg16_conv.trainable = False

#Use the generated model 
output_vgg16_conv = model_vgg16_conv(input)

#Add the fully-connected layers 
x = Flatten(name='flatten')(output_vgg16_conv)
# x = Dense(4096, activation='relu', name='fc1')(x)
# x = Dropout(.5)(x)
# x = Dense(64, activation='softmax', name='fc2')(x)
x = Dense(2, activation='softmax', name='predictions')(x)

#Create your own model 
my_model = Model(input=input, output=x)

#In the summary, weights and layers from VGG part will be hidden, but they will be fit during the training
# my_model.summary()
# Out:
# c:\users\hiro\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:25: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("im..., outputs=Tensor("pr...)`

# %% [markdown]
# ### Setting Data generating parameters and Checkpoints

# %%
# Load best model from models directory
model_path = "models/"

'''uncomment this to load existing model'''
# my_model = load_model(model_path + "my_model_generator_150X150.hdf5")  

# https://keras.io/preprocessing/image/
train_datagen = ImageDataGenerator(
    rotation_range = 40,
    horizontal_flip=True)

test_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
        'real_data/validation',
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        'real_data/train',
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical')

checkpointer = ModelCheckpoint(
    model_path + "reverse_training_validation.hdf5",
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    save_weights_only=False,
    mode='auto',
    period=1)

my_model.compile(loss='binary_crossentropy',
              optimizer='Adagrad',
              metrics=['accuracy'])
# Out:
# c:\users\hiro\anaconda3\envs\tensorflow\lib\site-packages\keras\models.py:291: UserWarning: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
#   warnings.warn('Error in loading the saved optimizer '
# Found 770 images belonging to 2 classes.
# Found 3016 images belonging to 2 classes.

# %%
'''Train'''
my_model.fit_generator(
        train_generator,
        steps_per_epoch=1000,
        epochs=4,
        validation_data=validation_generator,
        callbacks=[checkpointer])
# Out:
# Epoch 1/4
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0455 - acc: 0.9962
# c:\users\hiro\anaconda3\envs\tensorflow\lib\site-packages\PIL\TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 80000 bytes but only got 0. Skipping tag 64640
#   " Skipping tag %s" % (size, len(data), tag))
# c:\users\hiro\anaconda3\envs\tensorflow\lib\site-packages\PIL\TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 26214400 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# c:\users\hiro\anaconda3\envs\tensorflow\lib\site-packages\PIL\TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1050744 bytes but only got 8154. Skipping tag 56
#   " Skipping tag %s" % (size, len(data), tag))
# ...

# %% [markdown]
# ### Evaluating Model accuracy

# %%
'''Select model to evaluate'''
my_model = load_model("models/my_model_generator_150X150.hdf5")
# Out:
# c:\users\hiro\anaconda3\envs\tensorflow\lib\site-packages\keras\models.py:291: UserWarning: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
#   warnings.warn('Error in loading the saved optimizer '

# %%
'''Load all images into arrays'''
from PIL import Image
import glob
drone_images = []
# for filename in glob.glob('real_data/train_small/drone/*'):
#     im=Image.open(filename)
#     drone_images.append(im)
# for filename in glob.glob('real_data/validation/drone/*'):
#     im=Image.open(filename)
#     drone_images.append(im)
for filename in glob.glob('real_data/brians_gift/drone_dataset2/*'):
    im=Image.open(filename)
    drone_images.append(im)
    
not_drone_images = []
# for filename in glob.glob('real_data/train_small/not drone/*'):
#     im=Image.open(filename)
#     not_drone_images.append(im)
# for filename in glob.glob('real_data/validation/not drone/*'):
#     im=Image.open(filename)
#     im = im.convert('RGB')
#     not_drone_images.append(im)

y_label = np.r_[np.zeros(len(drone_images)), np.ones(len(not_drone_images))]
x_data = [np.array(im) for im in (drone_images + not_drone_images)]

# %%
'''Display one element in the loaded array'''
num = 71
print("label:\n", y_label[num])
print("prediction (one hot encoded): \n", my_model.predict(np.expand_dims(sc.misc.imresize(x_data[num],(150,150)), axis = 0)))
plt.imshow(x_data[num])
plt.show()
# Out:
# label:
#  0.0
# prediction (one hot encoded):
#  [[1.000000e+00 6.405848e-24]]
# c:\users\hiro\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   after removing the cwd from sys.path.

# %%
'''evaluate score for all loaded images'''
total_scores = []
total_accuracy = []
x_eval =  [np.expand_dims(sc.misc.imresize(im,(150,150)), axis = 0) for im in x_data]
y_eval = np.zeros((len(y_label),1, 2))
y_eval[np.arange(len(y_label)),np.zeros(len(y_label)).astype(int),y_label.astype(int)] = 1
for num in range(len(y_label)):
    score, acc = my_model.evaluate(x_eval[num], y_eval[num], verbose = False)
    total_scores.append(score)
    total_accuracy.append(int(np.around(acc)))
print(sum(total_scores))
print(np.mean(total_accuracy))
# Out:
# c:\users\hiro\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   after removing the cwd from sys.path.
# 279.0014188894551
# 0.8080808080808081

# %%
'''Show misclassified'''
filenames = glob.glob('real_data/brians_gift/drone_dataset2/*')
for idx, isCorrect in enumerate(total_accuracy):
    if isCorrect:
        print(filenames[idx])
#         plt.imshow(x_data[idx])
#         plt.show()
# Out:
# real_data/brians_gift/drone_dataset2\drone_rect1.jpg
# real_data/brians_gift/drone_dataset2\drone_rect10.jpg
# real_data/brians_gift/drone_dataset2\drone_rect20.jpg
# real_data/brians_gift/drone_dataset2\drone_rect21.jpg
# real_data/brians_gift/drone_dataset2\drone_rect22.jpg
# real_data/brians_gift/drone_dataset2\drone_rect23.jpg
# real_data/brians_gift/drone_dataset2\drone_rect24.jpg
# real_data/brians_gift/drone_dataset2\drone_rect25.jpg
# real_data/brians_gift/drone_dataset2\drone_rect26.jpg
# real_data/brians_gift/drone_dataset2\drone_rect27.jpg
# real_data/brians_gift/drone_dataset2\drone_rect28.jpg
# real_data/brians_gift/drone_dataset2\drone_rect29.jpg
# real_data/brians_gift/drone_dataset2\drone_rect30.jpg
# real_data/brians_gift/drone_dataset2\drone_rect31.jpg
# real_data/brians_gift/drone_dataset2\drone_rect32.jpg
# real_data/brians_gift/drone_dataset2\drone_rect33.jpg
# real_data/brians_gift/drone_dataset2\drone_rect34.jpg
# ...

# %%
'''Display datagenerator images'''
train_datagen = ImageDataGenerator(
    rotation_range = 0,
    horizontal_flip=False)

batches = train_datagen.flow_from_directory('real_data/train', target_size=(150,150),
      class_mode='categorical', batch_size=32)

x_batch, y_batch = next(batches)
for i in range (0,32):
    image = x_batch[i].astype(np.uint8)
    plt.figure()
    plt.title(y_batch[i].astype(int))
    plt.imshow(image)
    plt.show()
# Out:
# Found 3016 images belonging to 2 classes.

# %%
'''verify vgg layers have not changed, should be 0'''
np.sum(model_vgg16_conv.predict(np.ones([1,150,150,3])) != VGG16(weights='imagenet', include_top=False).predict(np.ones([1,150,150,3])))
# Out:
# 0

# %%
# Out:
# 1.0

# %%
'''Predict'''
if np.random.randint(2):
    num = np.random.randint(len(drone_images))
else:
    num = np.random.randint(len(not_drone_images)) + len(drone_images)
print(num)
print(y_label[num])
image = sc.misc.imresize(x_data[num],(150,150))

# predict the probability across all output classes
yhat = my_model.predict(np.expand_dims((image), axis=0))

# from keras.applications.vgg16 import decode_predictions
# # convert the probabilities to class labels
# label = decode_predictions(yhat)
# # retrieve the most likely result, e.g. highest probability
# label = label[0][0]
# # print the classification
# print('%s (%.2f%%)' % (label[1], label[2]*100))

print(yhat)
plt.imshow(image)
plt.show()
# Out:
# 9
# 0.0
# [[1. 0.]]
# c:\users\hiro\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
y_eval[0]
# Out:
# array([[0., 0.]])
